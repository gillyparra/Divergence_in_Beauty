# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np
import time
import csv
import json
from itertools import chain



# U20 wc called the youth wc for these years 
years = [1977, 1979, 1981, 1983, 1985, 1987, 1989, 1991, 1993, 1995, 1997, 1999, 2001, 2003, 2005]

# Initialize an empty list to store DataFrames
dfs = []

for year in years:
    # Construct the URL
    url = f'https://en.wikipedia.org/wiki/{year}_FIFA_World_Youth_Championship'
    
    # Fetch the page
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find the last "wikitable" on the page
    table = soup.find_all('table', {'class': "wikitable"})[-1]
    
    # Read the table into a DataFrame
    df_year = pd.read_html(str(table))[0]
    
    # Add a column for the year
    df_year['Year'] = year
    
    # Append the DataFrame to the list
    dfs.append(df_year)

# Concatenate all DataFrames into a single DataFrame
final_df = pd.concat(dfs, ignore_index=True)

# Drop rows where the 'Team' column is NaN
final_df.dropna(subset=['Team'], inplace=True)

# Drop the 'Final result' column
final_df.drop(columns=['Final result'], inplace=True)

# Drop the 'GD' column
final_df.drop(columns=['GD'], inplace=True)

# Display the first few rows of the final DataFrame
print(final_df.head())
# Out:
#    Pos          Team  Pld    W    D    L    GF   GA  Pts  Year
# 0  1.0  Soviet Union  5.0  2.0  3.0  0.0   7.0  4.0  7.0  1977
# 1  2.0        Mexico  5.0  1.0  4.0  0.0  11.0  5.0  6.0  1977
# 2  3.0        Brazil  5.0  3.0  2.0  0.0  13.0  3.0  8.0  1977
# 3  4.0       Uruguay  5.0  3.0  1.0  1.0   6.0  5.0  7.0  1977
# 5  5.0      Paraguay  3.0  2.0  0.0  1.0   6.0  2.0  4.0  1977

# %%
# You can then save this DataFrame to a CSV file if needed
final_df.to_csv('C:/Users/Guill/Downloads/U20 77-05.csv', index=False)

# %%
# Now u20 wc
years = [2005,2007,2009,2011,2013,2015,2017,2019,2023]

# Initialize an empty list to store DataFrames
dfs = []

for year in years:
    # Construct the URL
    url = f'https://en.wikipedia.org/wiki/{year}_FIFA_U-20_World_Cup'
    
    # Fetch the page
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find the last "wikitable" on the page
    table = soup.find_all('table', {'class': "wikitable"})[-1]
    
    # Read the table into a DataFrame
    df_year = pd.read_html(str(table))[0]
    
    # Add a column for the year
    df_year['Year'] = year
    
    # Append the DataFrame to the list
    dfs.append(df_year)

# Concatenate all DataFrames into a single DataFrame
final_df = pd.concat(dfs, ignore_index=True)

# Drop rows where the 'Team' column is NaN
final_df.dropna(subset=['Team'], inplace=True)

# Drop the 'Final result' column
final_df.drop(columns=['Final result'], inplace=True)

# Drop the 'GD' column
final_df.drop(columns=['GD'], inplace=True)

# Display the first few rows of the final DataFrame
print(final_df.head())
# Out:
#    Pos             Team  Pld    W    D    L    GF    GA   Pts  Year  \
# 0  1.0        Argentina  7.0  6.0  0.0  1.0  12.0   5.0  18.0  2005
# 1  2.0          Nigeria  7.0  3.0  2.0  2.0  10.0   5.0  11.0  2005
# 2  3.0           Brazil  7.0  5.0  1.0  1.0   9.0   4.0  16.0  2005
# 3  4.0          Morocco  7.0  3.0  1.0  3.0  11.0  10.0  10.0  2005
# 5  5.0  Netherlands (H)  5.0  4.0  1.0  0.0  10.0   2.0  13.0  2005
#
#   Golden Ball Silver Ball Bronze Ball
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 5         NaN         NaN         NaN

# %%
# You can then save this DataFrame to a CSV file if needed
final_df.to_csv('C:/Users/Guill/Downloads/U20 07-23.csv', index=False)

# %%
# Now u16 wc
years = [1985,1987,1989]

# Initialize an empty list to store DataFrames
dfs = []

for year in years:
    # Construct the URL
    url = f'https://en.wikipedia.org/wiki/{year}_FIFA_U-16_World_Championship'
    
    # Fetch the page
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find the last "wikitable" on the page
    table = soup.find_all('table', {'class': "wikitable"})[-1]
    
    # Read the table into a DataFrame
    df_year = pd.read_html(str(table))[0]
    
    # Add a column for the year
    df_year['Year'] = year
    
    # Append the DataFrame to the list
    dfs.append(df_year)

# Concatenate all DataFrames into a single DataFrame
final_df = pd.concat(dfs, ignore_index=True)

# Drop rows where the 'Team' column is NaN
final_df.dropna(subset=['Team'], inplace=True)

# Drop the 'GD' column
final_df.drop(columns=['GD'], inplace=True)


# You can then save this DataFrame to a CSV file if needed
final_df.to_csv('C:/Users/Guill/Downloads/U17 85-89.csv', index=False)

# %%
# Now u17 wc 1991–2005
years = [1991, 1993, 1995, 1997, 1999, 2001, 2003, 2005]

# Initialize an empty list to store DataFrames
dfs = []

for year in years:
    # Construct the URL
    url = f'https://en.wikipedia.org/wiki/{year}_FIFA_U-17_World_Championship'
    
    # Fetch the page
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find the last "wikitable" on the page
    table = soup.find_all('table', {'class': "wikitable"})[-1]
    
    # Read the table into a DataFrame
    df_year = pd.read_html(str(table))[0]
    
    # Add a column for the year
    df_year['Year'] = year
    
    # Append the DataFrame to the list
    dfs.append(df_year)

# Concatenate all DataFrames into a single DataFrame
final_df = pd.concat(dfs, ignore_index=True)

# Drop rows where the 'Team' column is NaN
final_df.dropna(subset=['Team'], inplace=True)

# Drop the 'GD' column
final_df.drop(columns=['GD'], inplace=True)


# You can then save this DataFrame to a CSV file if needed
final_df.to_csv('C:/Users/Guill/Downloads/U17 91-05.csv', index=False)

# %%
# Now u17 wc 2007-2023
years = [2007, 2009, 2011, 2013, 2015, 2017, 2019, 2021, 2023]

# Initialize an empty list to store DataFrames
dfs = []

for year in years:
    # Construct the URL
    url = f'https://en.wikipedia.org/wiki/{year}_FIFA_U-17_World_Cup'
    
    # Fetch the page
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find the last "wikitable" on the page
    table = soup.find_all('table', {'class': "wikitable"})[-1]
    
    # Read the table into a DataFrame
    df_year = pd.read_html(str(table))[0]
    
    # Add a column for the year
    df_year['Year'] = year
    
    # Append the DataFrame to the list
    dfs.append(df_year)

# Concatenate all DataFrames into a single DataFrame
final_df = pd.concat(dfs, ignore_index=True)

# Drop rows where the 'Team' column is NaN
final_df.dropna(subset=['Team'], inplace=True)

# Drop the 'GD' column
final_df.drop(columns=['GD'], inplace=True)


# You can then save this DataFrame to a CSV file if needed
final_df.to_csv('C:/Users/Guill/Downloads/U17 07-23.csv', index=False)

# %%
# Count frequencies of each unique value in the column
value_counts = df['Country'].value_counts()

# Get the top 20 most common values
top_20_values = value_counts.head(56)
print(top_20_values)
# Out:
# Italy             9511
# Argentina         8596
# Brazil            8231
# Spain             6148
# England           5035
# France            5025
# Germany           4784
# Poland            3730
# Greece            3693
# Portugal          3643
# Colombia          3569
# Indonesia         3366
# China             3231
# Mexico            3213
# South Africa      2894
# Serbia            2855
# Denmark           2823
# Australia         2790
# Turkey            2735
# Finland           2721
# Uruguay           2669
# Croatia           2620
# USA               2610
# Malaysia          2564
# Hungary           2480
# Israel            2471
# South Korea       2465
# Russia            2408
# Chile             2265
# Ukraine           2223
# Holland           2150
# Peru              2125
# Czech Republic    2125
# Bulgaria          2031
# Sweden            2023
# Romania           2003
# Scotland          1870
# Norway            1870
# Belarus           1655
# Ireland           1613
# ...

# %%
import requests
import json
import pandas as pd
from itertools import chain

# Modify the headers to include a User-Agent
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}

# Initialize an empty list to store formatted data from all rankings
all_rankings_formatted_data = []

# Combine the two ranges into a single iterable
id_ranges = chain(range(1, 154), range(8000, 14501))

for rank_id in id_ranges:
    url = f'https://www.fifa.com/api/ranking-overview?locale=en&dateId=id{rank_id}'
    
    response = requests.get(url, headers=headers)
    
    # Print progress
    print(f"Fetching rank id: {rank_id}")
    
    if response.status_code == 200:
        data = json.loads(response.text)
        
        # Extract ranking data
        rankings_list = data.get('rankings', [])
        
        # Check if rankings_list is not empty
        if rankings_list:
            # Process each ranking
            for ranking_data in rankings_list:
                all_rankings_formatted_data.append({
                    'dateId': f'id{rank_id}',  # Dynamic date ID
                    'country': ranking_data['rankingItem']['name'],
                    'rank': ranking_data['rankingItem']['rank'],
                    'previousRank': ranking_data['rankingItem']['previousRank'],
                    'totalPoints': ranking_data['rankingItem']['totalPoints'],
                    'previousPoints': ranking_data['previousPoints'],
                    'flagUrl': ranking_data['rankingItem']['flag']['src'],
                    'countryUrl': 'https://www.fifa.com' + ranking_data['rankingItem']['countryURL'],
                    'confederation': ranking_data['tag']['text'],
                })
        else:
            print("No rankings data found for this rank id.")
    else:
        print(f"Failed to fetch data for rank id {rank_id}. Status code:", response.status_code)
    
    
# Convert the collected data into a DataFrame
rankings_df = pd.DataFrame(all_rankings_formatted_data)
# Out:
# Fetching rank id: 1
# Fetching rank id: 2
# Fetching rank id: 3
# Fetching rank id: 4
# Fetching rank id: 5
# Fetching rank id: 6
# Fetching rank id: 7
# Fetching rank id: 8
# Fetching rank id: 9
# Fetching rank id: 10
# Fetching rank id: 11
# Fetching rank id: 12
# Fetching rank id: 13
# Fetching rank id: 14
# Fetching rank id: 15
# Fetching rank id: 16
# Fetching rank id: 17
# Fetching rank id: 18
# Fetching rank id: 19
# Fetching rank id: 20
# Fetching rank id: 21
# Fetching rank id: 22
# Fetching rank id: 23
# Fetching rank id: 24
# Fetching rank id: 25
# Fetching rank id: 26
# Fetching rank id: 27
# Fetching rank id: 28
# Fetching rank id: 29
# Fetching rank id: 30
# Fetching rank id: 31
# Fetching rank id: 32
# Fetching rank id: 33
# Fetching rank id: 34
# Fetching rank id: 35
# Fetching rank id: 36
# Fetching rank id: 37
# Fetching rank id: 38
# Fetching rank id: 39
# Fetching rank id: 40
# Fetching rank id: 41
# Fetching rank id: 42
# Fetching rank id: 43
# ...

# %%
rankings_df = pd.DataFrame(all_rankings_formatted_data)
print(rankings_df)
# Out:
#         dateId                 country   rank  previousRank  totalPoints  \
# 0          id1                 Germany    1.0           NaN        57.00
# 1          id1                   Italy    2.0           NaN        57.00
# 2          id1                  Brazil    3.0           NaN        56.00
# 3          id1                  Sweden    4.0           NaN        56.00
# 4          id1                 England    5.0           NaN        55.00
# ...        ...                     ...    ...           ...          ...
# 67266  id14338  British Virgin Islands  207.0         207.0       813.31
# 67267  id14338       US Virgin Islands  208.0         208.0       797.29
# 67268  id14338                Anguilla  209.0         209.0       793.48
# 67269  id14338              San Marino  210.0         210.0       742.05
# 67270  id14338                 Eritrea    NaN           NaN       855.56
#
#        previousPoints                                            flagUrl  \
# ...

# %%
rankings_df.to_csv(r'C:\Users\Guill\Downloads\fifa_world_rankings.csv', index=False)
